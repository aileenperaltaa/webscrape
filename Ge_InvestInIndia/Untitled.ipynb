# %%
import numpy as np
import pandas as pd

# %%
a = pd.read_csv("InvestIndia.csv")
b = pd.DataFrame(a)
b
# Out:
#                                                  Name  \
# 0                                      Mission Oxygen
# 1                           Gautam Gambhir Foundation
# 2                                    Mazdoor Kitchen
# 3                                       Breathe India
# 4                                   Chikka Foundation
# 5                                   Access Foundation
# 6                             Enrich Lives Foundation
# 7                                      Khaana Chahiye
# 8                                              Swasth
# 9                                   United Way Mumbai
# 10       Spoorthi Foundation- Coronavarus Relief Fund
# 11                                 Hemkunt Foundation
# 12                                  Sakina Foundation
# 13                                         ACT Grants
# 14                                   Feeding from Far
# 15          Tarai Environment Awareness Samiti (TEAS)
# ...

# %%
b['Email']
# Out:
# 0                                                   NaN
# 1                      info@gautamgambhirfoundation.org
# 2                                                   NaN
# 3                                ashu95.ranka@gmail.com
# 4                         : Santosh Kumar ,: 9570716800
# 5                                                   NaN
# 6                        team@enrichlivesfoundation.org
# 7                             contact@khaanachahiye.com
# 8                                       info@swasth.org
# 9                           contact@unitedwaymumbai.org
# 10                                 srivyal@sphoorti.org
# 11                        hemkuntfoundation13@gmail.com
# 12                                           9885178688
# 13                                 core-pm@actgrants.in
# 14                             feedingfromfar@gmail.com
# 15    ngoteasblp@gmail.com,Google Pay and UPI: 94150...
# 16                               foodbank@khalsaaid.org
# ...
